# %% [markdown]
# <a href="https://colab.research.google.com/github/saumyam2/Projects/blob/main/EDA_StudentPerformance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/StudentsPerformance.csv')

# %%
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.shape #(rows, columns) --> (x,y)
# Out:
# (1000, 8)

# %%
df['race/ethnicity'].unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
df.lunch
# Out:
# 0          standard
# 1          standard
# 2          standard
# 3      free/reduced
# 4          standard
#            ...
# 995        standard
# 996    free/reduced
# 997    free/reduced
# 998        standard
# 999    free/reduced
# Name: lunch, Length: 1000, dtype: object

# %%
value_counts = df['race/ethnicity'].value_counts()

# %%
value_counts
# Out:
# group C    319
# group D    262
# group B    192
# group E    140
# group A     89
# Name: race/ethnicity, dtype: int64

# %%
plt.bar(value_counts.index, value_counts.values)
plt.show()

# %%
plt.barh(value_counts.index, value_counts.values)
plt.show()

# %%
plt.pie(value_counts.values)
plt.show()

# %%
df.append('female', 'group B', 'bachelor\'s degree', 'standard', 'none', 72, 74,76)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-99f228202a67> in <cell line: 1>()
# ----> 1 df.append('female', 'group B', 'bachelor\'s degree', 'standard', 'none', 72, 74,76)
#
# TypeError: DataFrame.append() takes from 2 to 5 positional arguments but 9 were given

# %%
new_row = {'gender':'female','race/ethnicity':'group B','parental level of education': 'bachelor\'s degree','lunch': 'standard','test preparation course': 'none','math score': 72,'reading score': 74,'writing score':76}
df.loc[len(df)] = new_row
df
# data2 = pd.DataFrame(new_row, index=[0])
# data2
# Out:
#       gender race/ethnicity parental level of education         lunch  \
# 0     female        group B           bachelor's degree      standard
# 1     female        group C                some college      standard
# 2     female        group B             master's degree      standard
# 3       male        group A          associate's degree  free/reduced
# 4       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 996     male        group C                 high school  free/reduced
# 997   female        group C                 high school  free/reduced
# 998   female        group D                some college      standard
# 999   female        group D                some college  free/reduced
# 1000  female        group B           bachelor's degree      standard
#
#      test preparation course  math score  reading score  writing score
# ...

# %%
new_row = {'gender':'female','race/ethnicity':'group B','parental level of education': 'bachelor\'s degree','lunch': 'standard','reading score': 74,'writing score':76}
df.loc[1000] = new_row
df
# Out:
#       gender race/ethnicity parental level of education         lunch  \
# 0     female        group B           bachelor's degree      standard
# 1     female        group C                some college      standard
# 2     female        group B             master's degree      standard
# 3       male        group A          associate's degree  free/reduced
# 4       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 997   female        group C                 high school  free/reduced
# 998   female        group D                some college      standard
# 999   female        group D                some college  free/reduced
# 1000  female        group B           bachelor's degree      standard
# 1001  female        group B           bachelor's degree      standard
#
#      test preparation course  math score  reading score  writing score
# ...

# %%
df.fillna(0)
# Out:
#       gender race/ethnicity parental level of education         lunch  \
# 0     female        group B           bachelor's degree      standard
# 1     female        group C                some college      standard
# 2     female        group B             master's degree      standard
# 3       male        group A          associate's degree  free/reduced
# 4       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 997   female        group C                 high school  free/reduced
# 998   female        group D                some college      standard
# 999   female        group D                some college  free/reduced
# 1000  female        group B           bachelor's degree      standard
# 1001  female        group B           bachelor's degree             0
#
#      test preparation course  math score  reading score  writing score
# ...

# %%
df.fillna(np.mean(df, axis=0))
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3430: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
#       gender race/ethnicity parental level of education         lunch  \
# 0     female        group B           bachelor's degree      standard
# 1     female        group C                some college      standard
# 2     female        group B             master's degree      standard
# 3       male        group A          associate's degree  free/reduced
# 4       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 997   female        group C                 high school  free/reduced
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1002 entries, 0 to 1001
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1002 non-null   object
#  1   race/ethnicity               1002 non-null   object
#  2   parental level of education  1002 non-null   object
#  3   lunch                        1002 non-null   object
#  4   test preparation course      1001 non-null   object
#  5   math score                   1001 non-null   float64
#  6   reading score                1002 non-null   int64
#  7   writing score                1002 non-null   int64
# dtypes: float64(1), int64(2), object(5)
# memory usage: 102.7+ KB

# %%
df.describe()
# Out:
#         math score  reading score  writing score
# count  1001.000000    1002.000000    1002.000000
# mean     66.094905      69.178643      68.069860
# std      15.156648      14.587194      15.184615
# min       0.000000      17.000000      10.000000
# 25%      57.000000      59.000000      58.000000
# 50%      66.000000      70.000000      69.000000
# 75%      77.000000      79.000000      79.000000
# max     100.000000     100.000000     100.000000

# %%
df
# Out:
#       gender race/ethnicity parental level of education         lunch  \
# 0     female        group B           bachelor's degree      standard
# 1     female        group C                some college      standard
# 2     female        group B             master's degree      standard
# 3       male        group A          associate's degree  free/reduced
# 4       male        group C                some college      standard
# ...      ...            ...                         ...           ...
# 997   female        group C                 high school  free/reduced
# 998   female        group D                some college      standard
# 999   female        group D                some college  free/reduced
# 1000  female        group B           bachelor's degree      standard
# 1001  female        group B           bachelor's degree      standard
#
#      test preparation course  math score  reading score  writing score
# ...

# %%
df = df.fillna(np.mean(df, axis=0))
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3430: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)

# %%
xpoints = np.array([0,34,70])
ypoints = np.array([0,24,50])

plt.figure(figsize = (15,7))
plt.xlabel('X Coordinate')
plt.ylabel('Y Coordinate')
plt.plot(xpoints, ypoints, marker='o')
plt.title('Coordinates')
plt.show()

# %%
xpoints1 = np.array([0,10,74,118])
ypoints1 = np.array([10,139,20,48])
plt.scatter(xpoints, ypoints)
plt.scatter(xpoints1, ypoints1)
plt.show()

# %%
value_counts
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-52bbe32a532d> in <cell line: 1>()
# ----> 1 value_counts
#
# NameError: name 'value_counts' is not defined
